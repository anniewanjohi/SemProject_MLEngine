# %% [markdown]
# <a href="https://colab.research.google.com/github/anniewanjohi/SemProject_MLEngine/blob/main/Resume_Job_Fit_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets pandas -q

# %%
from datasets import load_dataset
import pandas as pd

dataset = load_dataset("cnamuangtoun/resume-job-description-fit")
df = dataset["train"].to_pandas()
df.head()
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# train.csv: reconstructing file:   0%|          |  0.00B / 53.4MB
# train.csv: downloading bytes:           |  0.00B
# test.csv: reconstructing file:   0%|          |  0.00B / 15.2MB
# test.csv: downloading bytes:           |  0.00B
# ...
# Generating test split:   0%|          | 0/1759 [00:00<?, ? examples/s]
#                                          resume_text  \
# 0  SummaryHighly motivated Sales Associate with e...
# 1  Professional SummaryCurrently working with Cat...
# 2  SummaryI started my construction career in Jun...
# 3  SummaryCertified Electrical Foremanwith thirte...
# 4  SummaryWith extensive experience in business/r...
#
#                                 job_description_text   label
# 0  Net2Source Inc. is an award-winning total work...  No Fit
# ...

# %%
## a. How many rows and columns are contained in the dataset?

# %%
df.shape
# Out:
# (6241, 3)

# %%
## b. What datatypes are contained in the dataset?

# %%
df.dtypes
# Out:
# resume_text             object
# job_description_text    object
# label                   object
# dtype: object

# %%
## c. Is the dataset complete? (no missing values)

# %%
df.isnull().sum()
# Out:
# resume_text             0
# job_description_text    0
# label                   0
# dtype: int64

# %%
## d. Slice first 15 and last 20 rows into df_sample

# %%
df_sample = pd.concat([df.head(15), df.tail(20)], ignore_index=True)

# %%
df_sample
# Out:
#                                           resume_text  \
# 0   SummaryHighly motivated Sales Associate with e...
# 1   Professional SummaryCurrently working with Cat...
# 2   SummaryI started my construction career in Jun...
# 3   SummaryCertified Electrical Foremanwith thirte...
# 4   SummaryWith extensive experience in business/r...
# 5   SummarySolution-oriented, results-driven strat...
# 6   SummaryA position in a company that will utili...
# 7   SummaryTo participate as a team member in a dy...
# 8   SummaryMore than ten years of progressive expe...
# 9   SummaryCERTIFIED SOFTWARE DEVELOPMENT PROFESSI...
# 10  SummaryI have studied Electrical Engineering w...
# 11  ExperienceData, Research & Marketing Consultan...
# 12  Professional SummaryHighly motivated Sales Ass...
# 13  Professional SummaryDetail-driven accounting p...
# 14  SummaryISTQB certified QA Test Analyst/Payment...
# 15  SummaryHonest, reliable, dependable, hardworki...
# ...
